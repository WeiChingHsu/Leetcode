# %% [markdown]
# ## 1848. Minimum Distance to the Target Element (Easy) [題目](https://leetcode.com/problems/minimum-distance-to-the-target-element/description/?envType=daily-question&envId=2026-04-13)

# %% [markdown]
# Given an integer array nums (0-indexed) and two integers target and start, find an index i such that nums[i] == target and abs(i - start) is minimized.
#
# Note that abs(x) is the absolute value of x.
#
# Return abs(i - start).
#
# It is guaranteed that target exists in nums.

# %% [markdown]
# ### 1. 暴力法

# %%
from typing import List
class Solution:
    def getMinDistance(self, nums: List[int], target: int, start: int) -> int:
        minDistance = float("inf")
        for index, num in enumerate(nums):
            if num == target:
                distance = abs(index - start)
                if distance < minDistance:
                    minDistance = distance

        return minDistance

# %% [markdown]
# ### 2. 從start向外擴展

# %%
class Solution:
    def getMinDistance(self, nums: List[int], target: int, start: int) -> int:
        
        for distance in range(len(nums)):
            # 檢查左邊
            if start + distance < len(nums) and nums[start + distance] == target:
                return distance
            # 檢查右邊
            if start - distance >= 0 and nums[start - distance] == target:
                return distance
