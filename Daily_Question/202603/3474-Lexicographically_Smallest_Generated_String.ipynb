# %% [markdown]
# ## 3474. Lexicographically Smallest Generated String (Hard)

# %% [markdown]
# You are given two strings, str1 and str2, of lengths n and m, respectively.
#
# A string word of length n + m - 1 is defined to be generated by str1 and str2 if it satisfies the following conditions for each index 0 <= i <= n - 1:
#
# * If str1[i] == 'T', the substring of word with size m starting at index i is equal to str2, i.e., word[i..(i + m - 1)] == str2.
# * If str1[i] == 'F', the substring of word with size m starting at index i is not equal to str2, i.e., word[i..(i + m - 1)] != str2.
#
# Return the lexicographically smallest possible string that can be generated by str1 and str2. If no string can be generated, return an empty string "".

# %% [markdown]
# ### 1. 一般解

# %%
class Solution:
    def generateString(self, str1: str, str2: str) -> str:
        n, m = len(str1), len(str2)
        total_len = n + m - 1
        res = [None] * total_len
        
        # 處理 'T'
        for i in range(n):
            if str1[i] == 'T':
                for k in range(m):
                    if res[i + k] is not None and res[i + k] != str2[k]:
                        return ""
                    res[i + k] = str2[k]
        
        satisfied = [False] * n
        none_count = [0] * n
        for j in range(n):
            if str1[j] == 'F':
                cnt = 0
                for k in range(m):
                    if res[j + k] is None:
                        cnt += 1
                    elif res[j + k] != str2[k]:
                        satisfied[j] = True
                none_count[j] = cnt

        for i in range(total_len):
            if res[i] is not None:
                continue

            forbidden_char = None
            for j in range(max(0, i - m + 1), min(n, i + 1)):
                if str1[j] == 'F' and not satisfied[j] and none_count[j] == 1:
                    forbidden_char = str2[i - j]
                    break
            
            if forbidden_char == 'a':
                res[i] = 'b'
            else:
                res[i] = 'a'
            
            for j in range(max(0, i - m + 1), min(n, i + 1)):
                if str1[j] == 'F':
                    none_count[j] -= 1
                    if res[i] != str2[i - j]:
                        satisfied[j] = True

        final_str = "".join(res)
        for i in range(n):
            window = final_str[i:i+m]
            if str1[i] == 'T' and window != str2: return ""
            if str1[i] == 'F' and window == str2: return ""
            
        return final_str

# %% [markdown]
# ### 2. KMP
